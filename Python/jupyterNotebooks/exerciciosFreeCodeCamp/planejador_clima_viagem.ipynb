# %% [markdown]
# 1 - Você deve criar as seguintes variáveis:
#
# * distance_mi (um número que representa a distância a percorrer em milhas)
# * is_raining (um booleano que representa se o usuário está atualmente enfrentando clima chuvoso)
# * has_bike (um booleano que representa se o usuário tem uma bicicleta)
# * has_car (um booleano que representa se o usuário tem um carro)
# * has_ride_share_app (um booleano que representa se o usuário tem um app que permite solicitar uma corrida)

# %% [markdown]
# ✅ 2 - Você deve usar declarações condicionais para determinar se o deslocamento é possível com base nos valores dessas variáveis.
#
# 3 - Você deve usar as declarações if, elif e else para avaliar as categorias de distância em ordem crescente.
#
# ✅ 4 - Se distance_mi for um valor falso:
# Você deve imprimir False.
#
# 5 - Se a distância for menor ou igual a 1 milha:
# Você deve imprimir True somente se não estiver chovendo.
# Caso contrário, você deve imprimir False.
#
# 6 - Se a distância for maior que 1 milha e menor ou igual a 6 milhas:
# Você deve imprimir True somente se a pessoa tiver uma bicicleta e não estiver chovendo.
# Caso contrário, você deve imprimir False.
#
# 7 - Se a distância for maior que 6 milhas:
# Você deve imprimir True se a pessoa tiver um carro ou um aplicativo de carona.
# Caso contrário, você deve imprimir False.
#
# ________________________________________________________________________________________________________________________________________________________
#
# Testes
# 1.  ✅ Você deve ter uma variável chamada distance_mi.
# 2.  ✅ Você deve atribuir um número à sua variável distance_mi.
# 3.  ✅ Você deve ter uma variável chamada is_raining.
# 4.  ✅ Você deve atribuir um booleano à sua variável is_raining.
# 5.  ✅ Você deve ter uma variável chamada has_bike.
# 6.  ✅ Você deve atribuir um booleano à sua variável has_bike.
# 7.  ✅ Você deve ter uma variável chamada has_car.
# 8.  ✅ Você deve atribuir um booleano à sua variável has_car.
# 9.  ✅ Você deve ter uma variável chamada has_ride_share_app.
# 10. ✅ Você deve atribuir um booleano à sua variável has_ride_share_app.
# 11. ✅ Você deve usar pelo menos uma declaração if.
# 12. ✅ Você deve usar pelo menos um ramo elif no seu programa.
# 13. ✅ Você deve usar pelo menos um operador booleano (and, or ou not) no seu código.
# 14. ✅ Você deve usar a função print() para exibir o resultado.
# 15. ✅ Quando a distância for 1 milha ou menos e não estiver chovendo, o programa deve imprimir True.
# 16. ✅ Quando a distância for 1 milha ou menos e estiver chovendo, o programa deve imprimir False.
# 17. ✅ Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), e estiver chovendo sem bicicleta, o programa deve imprimir False.
# 18. ✅ Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), não estiver chovendo e nenhuma bicicleta estiver disponível, o programa deve imprimir False.
# 19. ✅ Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), uma bicicleta estiver disponível e não estiver chovendo, o programa deve imprimir True.
# 20. ✅ Quando a distância for maior que 6 milhas e um aplicativo de carona estiver disponível, o programa deve imprimir True.
# 21. ✅ Quando a distância for maior que 6 milhas e um carro estiver disponível, o programa deve imprimir True.
# 22. ✅ Quando a distância for maior que 6 milhas e nenhum carro e nem um aplicativo de carona estiver disponível, o programa deve imprimir False.

# %% [markdown]
# 1️⃣ Teste do código por blocos

# %%
distance_mi = 0
is_raining = True
has_bike = False
has_car = False
has_ride_share_app = False

# %%
if distance_mi == 0:
    print("'False' condição 2 atendida")
# Out:
# 'False' condição 2 atendida

# %%
distance_mi = 0
is_raining = False

# %%
#15. Quando a distância for 1 milha ou menos e não estiver chovendo, o programa deve imprimir True.
#16. Quando a distância for 1 milha ou menos e estiver chovendo, o programa deve imprimir False.

if distance_mi <= 1:
    if not(is_raining):
        print("True 15")        
    else:
        print("False 16")
# Out:
# True 15

# %%
distance_mi = 5
is_raining = False
has_bike = False

# %%
# 17. Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), e estiver chovendo sem bicicleta, o programa deve imprimir False. 
# 18. Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), não estiver chovendo e nenhuma bicicleta estiver disponível, o programa deve imprimir False.
# 19. Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), uma bicicleta estiver disponível e não estiver chovendo, o programa deve imprimir True.

    
if distance_mi >= 1 and distance_mi <= 6:
    if is_raining and not(has_bike):
        print("False 17")
    elif not(is_raining) and not(has_bike):
        print("False 18")
    elif has_bike and not(is_raining):
        print("True 19")

# %%
distance_mi = 7
has_car = False
has_ride_share_app = False

# %%
# 20. Quando a distância for maior que 6 milhas e um aplicativo de carona estiver disponível, o programa deve imprimir True.
# 21. Quando a distância for maior que 6 milhas e um carro estiver disponível, o programa deve imprimir True.
# 22. Quando a distância for maior que 6 milhas e nenhum carro e nem um aplicativo de carona estiver disponível, o programa deve imprimir False.

if distance_mi > 6 and (has_car or has_ride_share_app) :
        print("True 20 ou 21")
else:
        print("False 22")
# Out:
# False 22

# %% [markdown]
# 2️⃣ Teste do código integrado

# %%
distance_mi = 7
is_raining = False
has_bike = True
has_car = False
has_ride_share_app = True

# 15. Quando a distância for 1 milha ou menos e não estiver chovendo, o programa deve imprimir True.
# 16. Quando a distância for 1 milha ou menos e estiver chovendo, o programa deve imprimir False.
# 17. Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), e estiver chovendo sem bicicleta, o programa deve imprimir False. 
# 18. Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), não estiver chovendo e nenhuma bicicleta estiver disponível, o programa deve imprimir False.
# 19. Quando a distância estiver entre 1 milha (excluída) e 6 milhas (incluídas), uma bicicleta estiver disponível e não estiver chovendo, o programa deve imprimir True.
# 20. Quando a distância for maior que 6 milhas e um aplicativo de carona estiver disponível, o programa deve imprimir True.
# 21. Quando a distância for maior que 6 milhas e um carro estiver disponível, o programa deve imprimir True.
# 22. Quando a distância for maior que 6 milhas e nenhum carro e nem um aplicativo de carona estiver disponível, o programa deve imprimir False.

# %%
if distance_mi == 0:
    print('False')
elif distance_mi <= 1:
    if not(is_raining):
        print("True 15")
    else:
        print("False 16")
elif distance_mi >= 1 and distance_mi <= 6:
    if is_raining and not(has_bike):
        print("False 17")
    elif not(is_raining) and not(has_bike):
        print("False 18")
    elif has_bike and not(is_raining):
        print("True 19")
elif distance_mi > 6 and (has_car or has_ride_share_app) :
        print("True 20 ou 21")
else:
    print("False 22")
# Out:
# True 20 ou 21
